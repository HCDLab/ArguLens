# %% [markdown]
# Information need to retrieve:
# 1. Author’s association with repository. (author_association) - done previously
# 2. Flag of whether the comment author also posted the original issue. (is_poster)
#
# 3. Length of the sentence in terms of character count. (quote_len)
# 4. Count of words in sentence divided by that of the longest sentence in thread. (percent_len_thread)
# 5. Count of words in sentence divided by that of the longest sentence in comment. (percent_len_comment)
# 6. Position of sentence in comment divided by the number of sentences in comment. (percent_pos_thread)
# 7. Position of sentence in conversation divided by the number of sentences in thread. (percent_pos_comment)
# 8. Flag of whether if this is in the first comment. (is_first_comment)
# 9. Flag of whether this is the last comment or not. (is_last_comment)
#
# 10. Time from beginning of conversation to comment divided by the total time of thread. (percent_start_time_thread)
# 11. Time from comment to end of conversation divided by the total time of thread. (percent_end_time_thread)
# 12. Time from previous comment to current comment (normalized). (percent_previous_time_thread)
# 13. Time from current comment to next comment (normalized). (percent_next_time_thread)
#
# 14. Flag to indicate whether the comment contains a code snippet. (contain_code)

# %%
import numpy as np
import pandas as pd
import re
import requests
import json
from datetime import datetime

# %%
datetime_format_github = '%Y-%m-%dT%H:%M:%SZ'

# %%
df_quote = pd.read_csv('AuthorAssociation_data.csv')

# %%
df_time_author = pd.read_excel('TimeAuthor.xlsx', sheet_name='Sheet1', usecols =['Text Content', 'Document', 'Codes', 'Start position', 'End position'])

# %%
def clean_text(line):
    ## Replace all code blocks with the token CODE
    pattern = re.compile(r'```[^```]*?(```|$)', re.MULTILINE|re.DOTALL)
    line = re.sub(pattern,'CODE_BLOCK',line)
    pattern = re.compile(r'`[^`]*?`', re.MULTILINE|re.DOTALL)
    line = re.sub(pattern,'CODE_SEGMENT',line)
    pattern = re.compile(r'(^|\n)>.*')
    line = re.sub(pattern,'\nQUOTE',line)
    pattern = re.compile(r'On [\d]+ \w+ [\d]+ at [\d]+:[\d]+, \w+ \w+ <.*?> wrote:')
    line = re.sub(pattern,'QUOTE',line)
    pattern = re.compile(r'On \w+, \w+ \d+, \d+, \d+:\d+ (A|P)M \w+ \w+ .*? wrote:')
    line = re.sub(pattern,'QUOTE',line)
    pattern = re.compile(r'([\n\t\s]*?QUOTE)+',re.MULTILINE|re.DOTALL)
    line = re.sub(pattern,'\nQUOTE',line)
    ## Replace URLs which are surrounded by brackets
    pattern = re.compile(r'[\[\(]http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+[\]\)]')
    line = re.sub(pattern,' URL ',line)
    pattern = re.compile(r'\B@\w+')
    line = re.sub(pattern,'SCREEN_NAME ',line)
    pattern = re.compile(r'\b([v])?([1-2]+\.)+(\d+\.)?(\*|\d+)\b')
    line = re.sub(pattern,'VERSION_NUM ',line)
    pattern = re.compile(r'\+(\d+)')
    line = re.sub(pattern,'PLUS_ONE',line)
    pattern = re.compile(r'\-(\d+)')
    line = re.sub(pattern,'MINUS_ONE',line)
    pattern = re.compile(r'\#(\d+)')
    line = re.sub(pattern,'ISSUE_REFERENCE',line)
    return line

# %%
df_quote['Text Content'] = df_quote['Text Content'].map(lambda row : clean_text(row))

# %%
# remove the data point with only non-ascii chars (e.g. only emoji, gibberish chinese)
def GetContainAlphabet(row):
    content = row['Text Content']
    pattern = re.compile(r'[a-zA-Z]+')
    alphabet_content = re.findall(pattern,content)
    if len(alphabet_content) > 0:
        return True
    else:
        return False

# %%
df_quote['contain_alphabet'] = df_quote.apply(GetContainAlphabet , axis=1)

# %%
df_quote[df_quote['contain_alphabet'] == False]
# Out:
#                                            Text Content  \
# 95                                                  ???
# 176                                                  ðª
# 226                                                 ð 1
# 276   è¿ä¸¤ä¸ªè®¾ç½®å¹¶ä¸è½è§£å³é®é¢ï¼æµªè´¹äºèå­å¥½...
# 282                                                   ð
# 290   __//_/|/â-//â-//â-//â-//â-//Â´Â¯/'--'/Â´Â¯`Â·_...
# 637                                                   ð
# 714                                                   ð
# 905                                                   ð
# 1187                                                  ð
# 1260                                                  ð
# 1546  æå¤çªå£è¿ä¸ªåè½æ´ä¸æï¼çä¸¤ä¸ªé¡¹ç®ä»¥ä¸çææ¡£æ¶...
# 1820  å®å¨åæ ï¼è¯·æ¯æåä¸ä¸ªçªå£ä¸­æå¼å¤ä¸ªé¡¹ç®æä»¶å...
# 3037                                                  ð
# 3112                                                  ð
# 3271                                               \+ 1
# 3597                                        -         1
# 4743                                                  ð
# 5122                                                 ;)
#
#                             Document  \
# 95     issue9388_allCommentsText.doc
# 176    issue9388_allCommentsText.doc
# 226    issue9388_allCommentsText.doc
# 276    issue9388_allCommentsText.doc
# 282    issue9388_allCommentsText.doc
# 290    issue9388_allCommentsText.doc
# 637    issue4865_allCommentsText.doc
# 714   issue14909_allCommentsText.doc
# 905   issue14909_allCommentsText.doc
# 1187  issue14909_allCommentsText.doc
# 1260  issue14909_allCommentsText.doc
# 1546    issue396_allCommentsText.doc
# 1820    issue396_allCommentsText.doc
# 3037    issue396_allCommentsText.doc
# 3112    issue396_allCommentsText.doc
# 3271    issue224_allCommentsText.doc
# 3597    issue224_allCommentsText.doc
# 4743    issue224_allCommentsText.doc
# 5122    issue224_allCommentsText.doc
#
#                                                   Codes  Start position  \
# 95                          9388_irrelevant, small talk           16103
# 176                            9388_irrelevant, like it           27797
# 226                            9388_irrelevant, like it           20244
# 276                                     9388_irrelevant           18626
# 282                                     9388_irrelevant           17412
# 290                                     9388_irrelevant           18693
# 637                                     4865_irrelevant           45950
# 714                           14909_irrelevant, like it            9476
# 905                           14909_irrelevant, like it           37384
# 1187                                   14909_irrelevant            6467
# 1260                                   14909_irrelevant           72273
# 1546  396_warrant 1, description of expected behavio...           42979
# 1820                                        396_claim 1           83951
# 3037                                     396_irrelevant           42860
# 3112                                     396_irrelevant          194103
# 3271                            224_irrelevant, like it           23977
# 3597                            224_irrelevant, like it           66778
# 4743                            224_irrelevant, like it          260267
# 5122                                     224_irrelevant          171349
#
#       End position              time_pre           author_pre  \
# 95           16106  2017-08-10T13:07:06Z              ShayBox
# 176          27801  2018-01-29T14:25:04Z              Montago
# 226          20250  2017-10-26T01:18:19Z  technoiswatchingyou
# 3037         GameMidlet               NONE             False
# 3112            bpasero               NONE             False
# 3271     ianwesterfield               NONE             False
# 3597              riclf               NONE             False
# 4743         aminroosta               NONE             False
# 5122             Mikewl               NONE             False

# %%
display(df_quote.shape)
df_quote = df_quote.loc[df_quote['contain_alphabet'] == True]

display(df_quote.shape)
# Out:
# (5142, 13)
# (5123, 13)

# %%
df_first_comment = df_time_author.sort_values(['Start position'],ascending=True).groupby('Document').head(2)
df_first_comment = df_first_comment.sort_values(['Start position'],ascending=True).groupby('Document').tail(1)

# %%
display(df_first_comment)
# Out:
#                             Text Content                        Document  \
# 772    2015-11-20T00:20:01Z inakianduaga    issue224_allCommentsText.doc
# 387          2015-11-21T07:13:47Z i5ting    issue396_allCommentsText.doc
# 89    2016-04-04T12:08:50Z alexandrudima   issue4865_allCommentsText.doc
# 1    2016-07-16T16:20:03Z brunnopleffken   issue9388_allCommentsText.doc
# 195         2016-11-03T14:49:49Z bpasero  issue14909_allCommentsText.doc
#
#            Codes  Start position  End position
# 772  time_author             413           446
# 387  time_author             543           570
# 89   time_author             577           611
# 1    time_author             722           757
# 195  time_author             848           876

# %%
# original issue poster
def GetPoster(row):
    doc_name = row['Document']
    df_temp_doc = df_time_author.loc[(df_time_author['Document'] == doc_name)]
    df_temp_poster = df_temp_doc.loc[df_temp_doc['Start position'].idxmin()]
    df_temp_poster = df_temp_poster['Text Content'].split()
    return df_temp_poster[0], df_temp_poster[1]

# %%
def GetIsFirstComment(row):
    doc_name = row['Document']
    temp_df = df_first_comment.loc[df_first_comment['Document'] == doc_name]
    temp_df = temp_df.iloc[0]
    time_author_list = temp_df['Text Content'].split()
    first_comment_time = time_author_list[0]
    first_comment_author = time_author_list[1]
    return (row['time_cur'] == first_comment_time) & (row['author_cur'] == first_comment_author)

# %%
df_quote[['poster_time', 'poster_name']]  = df_quote.apply(GetPoster, axis=1, result_type="expand")

# %%
df_quote['is_poster'] = df_quote.apply(lambda row: row['author_cur'] == row['poster_name'] , axis=1)

# %%
df_quote['quote_len'] = df_quote.apply(lambda row: row['End position'] - row['Start position'], axis=1)

# %%
df_quote['word_count'] = df_quote.apply(lambda row: len(row['Text Content'].split()), axis=1)

# %%
df_quote['max_thread_len'] = df_quote.groupby(['Document'])['word_count'].transform(max)
df_quote['max_comment_len'] = df_quote.groupby(['Document', 'time_cur', 'author_cur'])['word_count'].transform(max)
df_quote['percent_len_thread'] = df_quote.apply(lambda row: row['word_count']/row['max_thread_len'], axis=1)
df_quote['percent_len_comment'] = df_quote.apply(lambda row: row['word_count']/row['max_comment_len'], axis=1)

# %%
df_quote['rank_thread'] = df_quote.groupby('Document')['Start position'].rank('dense', ascending=True)
df_quote['rank_comment'] = df_quote.groupby(['Document', 'time_cur', 'author_cur'])['Start position'].rank('dense', ascending=True)
df_quote['max_rank_thread'] = df_quote.groupby(['Document'])['rank_thread'].transform(max)
df_quote['max_rank_comment'] = df_quote.groupby(['Document', 'time_cur', 'author_cur'])['rank_comment'].transform(max)
df_quote['percent_pos_thread'] = df_quote.apply(lambda row: row['rank_thread']/row['max_rank_thread'], axis=1)
df_quote['percent_pos_comment'] = df_quote.apply(lambda row: row['rank_comment']/row['max_rank_comment'], axis=1)

# %%
df_quote['is_first_comment'] = df_quote.apply(GetIsFirstComment, axis=1)

df_quote['is_last_comment'] = df_quote.apply(lambda row: row['rank_thread'] == row['max_rank_thread'], axis=1)

# %%
def GetDateTimeObjects(row):
    date_time_pre = row['time_pre']
    date_time_cur = row['time_cur']
    date_time_next = row['time_next']
    rex = re.compile("^\d\d\d\d-(0?[1-9]|1[0-2])-(0?[1-9]|[12][0-9]|3[01])T(00|0[0-9]|1[0-9]|2[0-3]):([0-9]|[0-5][0-9]):([0-9]|[0-5][0-9])Z$")
    if (not pd.isna(date_time_cur)) and rex.match(date_time_cur) != None:
        cur_datetime_object = datetime.strptime(date_time_cur, datetime_format_github)
        if (not pd.isna(date_time_pre)) and rex.match(date_time_pre) != None:
            pre_datetime_object = datetime.strptime(date_time_pre, datetime_format_github)
        else:
            pre_datetime_object = cur_datetime_object
        if (not pd.isna(date_time_next)) and rex.match(date_time_next) != None:
            next_datetime_object = datetime.strptime(date_time_next, datetime_format_github)
        else:
            next_datetime_object = cur_datetime_object
    else:
#         print(row['Text Content'])
        print("cur " + date_time_cur)
        cur_datetime_object = datetime.min
        pre_datetime_object = cur_datetime_object
        next_datetime_object = cur_datetime_object
    return pre_datetime_object, cur_datetime_object, next_datetime_object

# %%
df_quote[['pre_datetime_object', 'cur_datetime_object', 'next_datetime_object']] = df_quote.apply(GetDateTimeObjects, axis=1, result_type="expand")

df_quote['start_datetime_object'] = df_quote.groupby(['Document'])['cur_datetime_object'].transform(min)
df_quote['end_datetime_object'] = df_quote.groupby(['Document'])['cur_datetime_object'].transform(max)

df_quote['duration_thread'] = df_quote.apply(lambda row: (row['end_datetime_object'] - row['start_datetime_object']).total_seconds(), axis=1)
df_quote['duration_start_to_cur'] = df_quote.apply(lambda row: (row['cur_datetime_object'] - row['start_datetime_object']).total_seconds(), axis=1)
df_quote['duration_cur_to_end'] = df_quote.apply(lambda row: (row['end_datetime_object'] - row['cur_datetime_object']).total_seconds(), axis=1)
df_quote['duration_pre_to_cur'] = df_quote.apply(lambda row: (row['cur_datetime_object'] - row['pre_datetime_object']).total_seconds(), axis=1)
df_quote['duration_cur_to_next'] = df_quote.apply(lambda row: (row['next_datetime_object'] - row['cur_datetime_object']).total_seconds(), axis=1)

df_quote['percent_start_time_thread'] = df_quote.apply(lambda row: row['duration_start_to_cur']/row['duration_thread'], axis=1)
df_quote['percent_end_time_thread'] = df_quote.apply(lambda row: row['duration_cur_to_end']/row['duration_thread'], axis=1)
df_quote['percent_previous_time_thread'] = df_quote.apply(lambda row: row['duration_pre_to_cur']/row['duration_thread'], axis=1)
df_quote['percent_next_time_thread'] = df_quote.apply(lambda row: row['duration_cur_to_next']/row['duration_thread'], axis=1)

# %%
df_comment = df_quote.groupby(['author_cur', 'time_cur', 'Document'])

# %%
def ContainCode(row):
    author = row['author_cur']
    time = row['time_cur']
    document = row['Document']
    same_comment = df_comment.get_group((author, time, document))
    for comment in same_comment['Text Content'].tolist():
        if (('CODE_SEGMENT' in comment) | ('CODE_BLOCK' in comment)):
            return True
    return False

# %%
df_quote['contain_code'] = df_quote.apply(ContainCode, axis=1)

# %%
pd.set_option('display.max_colwidth', -1)

display(df_quote)
# Out:
#                                                                                                                                                                                                           Text Content  \
# 0     Is it possible to add feature in order to force vscode to open file only by double clicking on it,  single click should only select a file in explorer ?
# 1     This can be very useful when there is a lot of files and you looking the exact one in explorer.
# 2     I'm using VS Code VERSION_NUM  Insider, but I think VERSION_NUM  behaves the same way: single-click just to select and preview the file; double-click already open it.
# 3     otherwise there is no reason for double click
# 4     SCREEN_NAME  The 'preview' function does not keep the file open when you preview or open another file in the same editor stack (unless you edit the previewed file, which makes the file opened).
# 5     Not sure what you are going for here, why would you actually (left-)click the file if you do not intend to do anything with it?
# 6     I also am trying to figure out how to do this
# 7     because I want the explorer panel to have focus, I might then use the arrow keys to scroll up and down in the list of files for me.
# 8     I was hoping I could type the name of a file and it's scroll to the next file it found starting with that letter.
# 9     even with KB focus in the explorer window it doesn't do this.
# 10    I want [enter] or [double click] to open the file.
# 11    I'm also having this trouble.
# 12    Most of the time I want to drag and drop files into the editor from the explorer bar.
# 13    As soon I select a file to drag, it opens it in preview mode and I lose the focus of the current editing file in editor.
# 14    I really dislike this "feature" of VS Code.
# 15    I want to disable automatic previewing of any file just because I have single-clicked it.
# 16    I would much rather double-click to open only.
# 17    I hate the "Preview Tab" feature of the full Visual Studio and I hate it in VSCode too.
# 18    Has anyone found a way to turn this off yet?
# 19    How do we achieve this?
# 20    I found a really klunky workaround - if you right-click the Explorer pane and then hit CODE_SEGMENT to hide the menu, the Explorer pane retains focus and then you can use the keyboard to navigate your folder.
# 21    SCREEN_NAME  You can also use the shortcut (Ctrl+Shift+E) to switch focus to explorer, or if you really want to use the mouse, you can middle-click and prevent the right-click menu that way.
# 22    SCREEN_NAME  when I tried that earlier today it opened the file that received focus in the explorer tree immediately.
# 23    This preview feature indeed is super annoying.
# 24    Please provide a way to disable it or some guidance on how to change it manually in the code.
# 25    nthing the calls for this.
# 26    i single click to get into the explorer tree to use my mouse wheel to scroll up or down or to make a particular file highlighted.
# 27    i dont want it to do anything, i dont want to flash another window i just want to scroll up or down without losing where i am in my file.
# 28    SCREEN_NAME  i don't like the comment "Not sure what you are going for here, why would you actually (left-)click the file if you do not intend to do anything with it?".
# 29    i might do it because i missclicked it.
# ...                                       ...
# 5111  Decided to check out VS Code to see if it could be a free replacement for Sublime,
# 5112  Just my 2Â¢...
# 5113  I use <kbd>Ctrl</kbd> + <kbd>Tab</kbd> quite a lot in VSCode
# 5114  We'd like to keep "preview files,"
# 5115  Thanks!
# 5116  You are always able to memorize few more lines, don't you?
# 5117  I'm sure you have your own preservative on things and how you would like them to work!
# 5118  But for issues which you wish to gain traction, is really the "Add your reaction" the equivalent?
# 5119  But possibly the other idea could pave ways to a new standard navigation UI.
# 5120  It was a very interesting point of view.
# 5121  SCREEN_NAME  I don't think that limiting the number of tabs is a good idea
# 5123  There are somethings that need innovating but first one has to ask, what about the workflow can we make better by removing tabs.
# 5124  Well for me, every single editor I use for development has a tab interface
# 5125  Code has Sublime, Atom, and non-editors like browsers to look to for making tabs "right."
# 5126  I recently used a tabbed editor (Koding.io) when I didn't have access to VSCode
# 5127  I don't remember how I opened a file or whether I happen to have edited it
# 5128  and I find it really disconcerting when files vanish seemingly at random. (I know it isn't random but it might as well be.)
# 5129  Please, please do what browsers do,
# 5130  we will shrink the tabs so that only the name of the file and the close button are visible.
# 5131  I tried out using the file history as suggested, and after a month
# 5132  these are the default shortcuts for navigating around tabs in other applications
# 5133  Double-clicking a tab may be useful for other things in future.
# 5134  it has max tab width, left/right scroll buttons, drop-menu listing all tabs (with the currently-visible tabs marked), etc.
# 5135  I hope when this is built it will be optional
# 5136  I hope we get tabs soon!
# 5137  Great News ..
# 5138  Our intent was to focus on the interaction flow, not the visual design so the tools in PowerPoint work fine for that level of detail.
# 5139  for example, I love the way
# 5140  Keep it along with tabs ?
# 5141  then thatâs all Iâd need/want.
#
#                            Document  \
# 0     issue9388_allCommentsText.doc
# 1     issue9388_allCommentsText.doc
# 2     issue9388_allCommentsText.doc
# 3     issue9388_allCommentsText.doc
# 4     issue9388_allCommentsText.doc
# 5     issue9388_allCommentsText.doc
# 6     issue9388_allCommentsText.doc
# 7     issue9388_allCommentsText.doc
# 8     issue9388_allCommentsText.doc
# 9     issue9388_allCommentsText.doc
# 10    issue9388_allCommentsText.doc
# 11    issue9388_allCommentsText.doc
# 12    issue9388_allCommentsText.doc
# 13    issue9388_allCommentsText.doc
# 14    issue9388_allCommentsText.doc
# 15    issue9388_allCommentsText.doc
# 16    issue9388_allCommentsText.doc
# 17    issue9388_allCommentsText.doc
# 18    issue9388_allCommentsText.doc
# 19    issue9388_allCommentsText.doc
# 20    issue9388_allCommentsText.doc
# 21    issue9388_allCommentsText.doc
# 22    issue9388_allCommentsText.doc
# 23    issue9388_allCommentsText.doc
# 24    issue9388_allCommentsText.doc
# 25    issue9388_allCommentsText.doc
# 26    issue9388_allCommentsText.doc
# 27    issue9388_allCommentsText.doc
# 28    issue9388_allCommentsText.doc
# 29    issue9388_allCommentsText.doc
# ...                             ...
# 5111  issue224_allCommentsText.doc
# 5112  issue224_allCommentsText.doc
# 5113  issue224_allCommentsText.doc
# 5114  issue224_allCommentsText.doc
# 5115  issue224_allCommentsText.doc
# 5116  issue224_allCommentsText.doc
# 5117  issue224_allCommentsText.doc
# 5118  issue224_allCommentsText.doc
# 5119  issue224_allCommentsText.doc
# 5120  issue224_allCommentsText.doc
# 5121  issue224_allCommentsText.doc
# 5123  issue224_allCommentsText.doc
# 5124  issue224_allCommentsText.doc
# 5125  issue224_allCommentsText.doc
# 5126  issue224_allCommentsText.doc
# 5127  issue224_allCommentsText.doc
# 5128  issue224_allCommentsText.doc
# 5129  issue224_allCommentsText.doc
# 5130  issue224_allCommentsText.doc
# 5131  issue224_allCommentsText.doc
# 5132  issue224_allCommentsText.doc
# 5133  issue224_allCommentsText.doc
# 5134  issue224_allCommentsText.doc
# 5135  issue224_allCommentsText.doc
# 5136  issue224_allCommentsText.doc
# 5137  issue224_allCommentsText.doc
# 5138  issue224_allCommentsText.doc
# 5139  issue224_allCommentsText.doc
# 5140  issue224_allCommentsText.doc
# 5141  issue224_allCommentsText.doc
#
#                                                                          Codes  \
# 0     9388_claim 1, description of expected behaviour
# 1     9388_warrant 1, feature motivation and use cases
# 2     9388_irrelevant, discuss issue source
# 3     9388_warrant 1, clarification of expected behaviour
# 4     9388_data 1, 9388_rebuttal 1, discuss issue source
# 5     9388_rebuttal 1, 9388_warrant 1, question about motivation and use cases
# 6     9388_warrant 1, small talk
# 7     9388_warrant 1, feature motivation and use cases
# 8     9388_warrant 1, feature motivation and use cases
# 9     9388_data 1, feature motivation and use cases
# 10    9388_claim 1, description of expected behaviour
# 11    9388_warrant 1, small talk
# 12    9388_warrant 1, feature motivation and use cases
# 13    9388_data 1, feature motivation and use cases
# 14    9388_warrant 1, small talk
# 15    9388_claim 1, description of expected behaviour
# 16    9388_claim 1, description of expected behaviour
# 17    9388_warrant 1, small talk
# 18    9388_irrelevant, question about progress
# 19    9388_irrelevant, small talk
# 20    9388_irrelevant, workaround details
# 21    9388_irrelevant, workaround details
# 22    9388_irrelevant, limitations of workarounds
# 23    9388_warrant 1, expressions
# 24    9388_claim 1, description of expected behaviour
# 25    9388_irrelevant, small talk
# 26    9388_data 1, feature motivation and use cases
# 27    9388_warrant 1, feature motivation and use cases
# 28    9388_warrant 1, expressions
# 29    9388_warrant 1, feature motivation and use cases
# ...                                                ...
# 5111  224_data 1
# 5112  224_irrelevant
# 5113  224_data 1
# 5114  224_claim 27, 224_rebuttal 27
# 5115  224_irrelevant
# 5116  224_rebuttal 6, 224_warrant 6
# 5117  224_irrelevant
# 5118  224_irrelevant
# 5119  224_rebuttal 28, 224_warrant 28
# 5120  224_rebuttal 1, 224_warrant 1
# 5121  224_claim 15, 224_rebuttal 15
# 5123  224_warrant 29
# 5124  224_data 29
# 5125  224_warrant 1
# 5126  224_data 1, 224_rebuttal 1
# 5127  224_data 33
# 5128  224_warrant 33
# 5129  224_claim 37, 224_rebuttal 37
# 5130  224_claim 39
# 5131  224_data 1, 224_rebuttal 1
# 5132  224_data 42
# 5133  224_irrelevant
# 5134  224_data 44
# 5135  224_claim 5
# 5136  224_claim 1
# 5137  224_irrelevant
# 5138  224_irrelevant
# 5139  224_warrant 49
# 5140  224_claim 5
# 5141  224_claim 46
#
#       Start position  End position              time_pre        author_pre  \
# 0     393             545           NaN                   NaN
# 1     546             641           NaN                   NaN
# 2     760             913           2016-07-16T14:48:59Z  ivalexa
# 29    0.754053                 0.012388
# ...        ...                      ...
# 5111  0.361185                 0.000236
# 5112  0.360614                 0.000114
# 5113  0.360585                 0.000009
# 5114  0.355663                 0.000067
# 5115  0.339201                 0.002927
# 5116  0.331828                 0.000649
# 5117  0.330353                 0.000032
# 5118  0.330181                 0.000171
# 5119  0.329362                 0.000548
# 5120  0.328320                 0.001042
# 5121  0.327526                 0.000794
# 5123  0.327208                 0.000280
# 5124  0.327208                 0.000280
# 5125  0.314035                 0.000042
# 5126  0.310489                 0.000166
# 5127  0.300825                 0.000058
# 5128  0.300825                 0.000058
# 5129  0.270184                 0.000346
# 5130  0.270055                 0.000093
# 5131  0.264688                 0.002683
# 5132  0.264660                 0.000029
# 5133  0.257120                 0.000433
# 5134  0.257120                 0.000433
# 5135  0.219182                 0.016418
# 5136  0.217359                 0.000112
# 5137  0.217044                 0.000316
# 5138  0.216367                 0.000109
# 5139  0.210294                 0.004755
# 5140  0.217044                 0.000316
# 5141  0.218982                 0.000200
#
#       percent_next_time_thread  contain_code
# 0     0.000112                  False
# 1     0.000112                  False
# 2     0.000030                  False
# 3     0.000391                  False
# 4     0.007601                  False
# 5     0.007601                  False
# 6     0.058459                  False
# 7     0.058459                  False
# 8     0.058459                  False
# 9     0.058459                  False
# 10    0.058459                  False
# 11    0.122348                  False
# 12    0.122348                  False
# 13    0.122348                  False
# 14    0.016924                  False
# 15    0.016924                  False
# 16    0.016924                  False
# 17    0.003600                  False
# 18    0.003600                  False
# 19    0.016924                  False
# 20    0.000361                  True
# 21    0.000029                  False
# 22    0.023703                  False
# 23    0.012388                  False
# 24    0.012388                  False
# 25    0.000174                  False
# 26    0.000174                  False
# 27    0.000174                  False
# 28    0.000174                  False
# 29    0.000174                  False
# ...        ...                    ...
# 5111  0.000245                  False
# 5112  0.000019                  False
# 5113  0.004177                  False
# 5114  0.000038                  False
# 5115  0.006508                  False
# 5116  0.001129                  True
# 5117  0.000171                  False
# 5118  0.000271                  False
# 5119  0.001042                  False
# 5120  0.000794                  False
# 5121  0.000024                  False
# 5123  0.000111                  False
# 5124  0.000111                  False
# 5125  0.000333                  False
# 5126  0.000061                  False
# 5127  0.000024                  False
# 5128  0.000024                  False
# 5129  0.000028                  False
# 5130  0.000049                  False
# 5131  0.000029                  False
# 5132  0.000018                  True
# 5133  0.010190                  False
# 5134  0.010190                  False
# 5135  0.000200                  False
# 5136  0.000316                  False
# 5137  0.000088                  False
# 5138  0.000091                  False
# 5139  0.000334                  True
# 5140  0.000088                  False
# 5141  0.000048                  False
#
# [5123 rows x 45 columns]

# %%
header = ['Text Content', 'Document', 'Codes',
          'author_association', 'is_poster', 
          'quote_len', 'percent_len_thread', 
          'percent_len_comment', 'percent_pos_thread', 
          'percent_pos_comment', 'is_first_comment',
          'is_last_comment', 'percent_start_time_thread',
          'percent_end_time_thread', 'percent_previous_time_thread',
          'percent_next_time_thread', 'contain_code']

df_quote.to_csv('Conversational_data.csv', columns=header, index=False)
