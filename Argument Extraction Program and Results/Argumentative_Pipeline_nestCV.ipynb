# %%
import numpy as np
import pandas as pd
import collections
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.pipeline import FeatureUnion, _fit_transform_one, _transform_one
from imblearn.pipeline import Pipeline as Imb_Pipeline
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from imblearn.over_sampling import SMOTE
import warnings
import time
import FilterDFTool
from nltk.stem import WordNetLemmatizer
from string import punctuation
from nltk.corpus import stopwords
import spacy
from nltk.stem.snowball import SnowballStemmer
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from DenseTfidfVectorizer import DenseTfidfVectorizer
from joblib import Parallel, delayed
from scipy import sparse
import re
from sklearn.svm import LinearSVC
from sklearn.exceptions import ConvergenceWarning
from functools import partial, update_wrapper
from sklearn.metrics import precision_recall_fscore_support, classification_report, accuracy_score, make_scorer, confusion_matrix
from sklearn.naive_bayes import ComplementNB
from sklearn.feature_selection import SelectKBest, chi2

warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Read data

# %%
experiment_setups = [
                     [True, False, False, False, False, 'svm', -1], #tfidf
                     [False, True, False, False, False, 'svm', -1], # conversational
                     [False, False, True, False, False, 'svm', -1], # liwc
                     [False, False, False, True, False, 'svm', -1], # politeness
                     [False, False, False, False, True, 'svm', -1], # pos_tfidf
                     [True, True, True, True, True, 'svm', -1],
                     [True, False, False, False, False, 'cnb', -1], #tfidf
                     [False, True, False, False, False, 'cnb', -1], # conversational
                     [False, False, True, False, False, 'cnb', -1], # liwc
                     [False, False, False, True, False, 'cnb', -1], # politeness
                     [False, False, False, False, True, 'cnb', -1], # pos_tfidf
                     [True, True, True, True, True, 'cnb', -1]
]

# each correspondes to these keys
# 1. use_tfidf 
# 2. use_conversational
# 3. use_liwc
# 4. use_politeness
# 5. use_pos_tfidf

# %%
df = pd.read_csv('Preprocessed.csv')
booleanDictionary = {'True': True, 'False': False}
df.replace(booleanDictionary, inplace=True)

# %%
label_col = 'is_non_argumentative'

text_content_name = ['Text Content']
conver_feature_name = ['author_association', 'is_poster', 'quote_len',
       'percent_len_thread', 'percent_len_comment', 'percent_pos_thread',
       'percent_pos_comment', 'is_first_comment', 'is_last_comment',
       'percent_start_time_thread', 'percent_end_time_thread',
       'percent_previous_time_thread', 'percent_next_time_thread',
       'contain_code']
liwc_feature_name = ['WC', 'Analytic', 'Clout', 'Authentic', 'Tone', 'WPS', 'Sixltr',
       'Dic', 'function', 'pronoun', 'ppron', 'i', 'we', 'you', 'shehe',
       'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj',
       'negate', 'verb', 'adj', 'compare', 'interrog', 'number', 'quant',
       'affect', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'social',
       'family', 'friend', 'female', 'male', 'cogproc', 'insight', 'cause',
       'discrep', 'tentat', 'certain', 'differ', 'percept', 'see', 'hear',
       'feel', 'bio', 'body', 'health', 'sexual', 'ingest', 'drives',
       'affiliation', 'achieve', 'power', 'reward', 'risk', 'focuspast',
       'focuspresent', 'focusfuture', 'relativ', 'motion', 'space', 'time',
       'work', 'leisure', 'home', 'money', 'relig', 'death', 'informal',
       'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'AllPunc',
       'Period', 'Comma', 'Colon', 'SemiC', 'QMark', 'Exclam', 'Dash',
       'Quote', 'Apostro', 'Parenth', 'OtherP']
politeness_feature_name = ['polite_score']
pos_str_name = ['pos_str']

# %%
full_feature_name = text_content_name + conver_feature_name + liwc_feature_name + politeness_feature_name + pos_str_name

irrelevant_source_data_pipeline = Pipeline([
    ('filtered_source', FilterDFTool.GetDataRowByLabels([], [])),
    ('data_cols', FilterDFTool.GetDataColByNames( np.append(label_col, full_feature_name)))
])

# %%
source_data = irrelevant_source_data_pipeline.fit_transform(X=df)

# %%
source_data['author_association'].unique()
# Out:
# array(['NOT FOUND', 'CONTRIBUTOR', 'NONE', 'MEMBER'], dtype=object)

# %%
pd.options.mode.chained_assignment = None  # default='warn'
source_data.loc[source_data['author_association'] == 'NOT FOUND', 'author_association'] = 0
source_data.loc[source_data['author_association'] == 'NONE', 'author_association'] = 1
source_data.loc[source_data['author_association'] == 'CONTRIBUTOR', 'author_association'] = 2
source_data.loc[source_data['author_association'] == 'MEMBER', 'author_association'] = 3

# %%
display(source_data)
# Out:
#       is_irrelevant                                       Text Content  \
# 0             False  Is it possible to add feature in order to forc...
# 1             False  This can be very useful when there is a lot of...
# 2              True  I'm using VS Code VERSION_NUM  Insider, but I ...
# 3             False      otherwise there is no reason for double click
# 4             False  SCREEN_NAME  The 'preview' function does not k...
# 5             False  Not sure what you are going for here, why woul...
# 6             False      I also am trying to figure out how to do this
# 7             False  because I want the explorer panel to have focu...
# 8             False  I was hoping I could type the name of a file a...
# 9             False  even with KB focus in the explorer window it d...
# 10            False  I want [enter] or [double click] to open the f...
# 11            False                      I'm also having this trouble.
# 12            False  Most of the time I want to drag and drop files...
# 13            False  As soon I select a file to drag, it opens it i...
# 14            False        I really dislike this "feature" of VS Code.
# 15            False  I want to disable automatic previewing of any ...
# 16            False     I would much rather double-click to open only.
# 17            False  I hate the "Preview Tab" feature of the full V...
# 18             True       Has anyone found a way to turn this off yet?
# 19             True                            How do we achieve this?
# 20             True  I found a really klunky workaround - if you ri...
# 21             True  SCREEN_NAME  You can also use the shortcut (Ct...
# 22             True  SCREEN_NAME  when I tried that earlier today i...
# 23            False     This preview feature indeed is super annoying.
# 24            False  Please provide a way to disable it or some gui...
# 25             True                         nthing the calls for this.
# 26            False  i single click to get into the explorer tree t...
# 27            False  i dont want it to do anything, i dont want to ...
# 28            False  SCREEN_NAME  i don't like the comment "Not sur...
# 29            False            i might do it because i missclicked it.
# ...             ...                                                ...
# 5093          False  Decided to check out VS Code to see if it coul...
# 5094           True                                     Just my 2Â¢...
# 5095          False  I use <kbd>Ctrl</kbd> + <kbd>Tab</kbd> quite a...
# 5096          False                 We'd like to keep "preview files,"
# 5097           True                                            Thanks!
# 5098          False  You are always able to memorize few more lines...
# 5099           True  I'm sure you have your own preservative on thi...
# 5100           True  But for issues which you wish to gain traction...
# 5101          False  But possibly the other idea could pave ways to...
# 5102          False           It was a very interesting point of view.
# 5103          False  SCREEN_NAME  I don't think that limiting the n...
# 5104          False  There are somethings that need innovating but ...
# 5105          False  Well for me, every single editor I use for dev...
# 5106          False  Code has Sublime, Atom, and non-editors like b...
# 5107          False  I recently used a tabbed editor (Koding.io) wh...
# 5108          False  I don't remember how I opened a file or whethe...
# 5109          False  and I find it really disconcerting when files ...
# 5110          False                Please, please do what browsers do,
# 5111          False  we will shrink the tabs so that only the name ...
# 5112          False  I tried out using the file history as suggeste...
# 5113          False  these are the default shortcuts for navigating...
# 5114           True  Double-clicking a tab may be useful for other ...
# 5115          False  it has max tab width, left/right scroll button...
# 5116          False      I hope when this is built it will be optional
# 5117          False                           I hope we get tabs soon!
# 5118           True                                      Great News ..
# 5119           True  Our intent was to focus on the interaction flo...
# 5120          False                        for example, I love the way
# 5121          False                          Keep it along with tabs ?
# 5122          False                     then thatâs all Iâd need/want.
#
#       author_association  is_poster  quote_len  percent_len_thread  \
# 0                      0       True        152            0.750000
# 1                      0       True         95            0.500000
# 2                      2      False        153            0.650000
# 3                      1       True         45            0.200000
# 4                      2      False        190            0.825000
# 5                      2      False        127            0.625000
# 6                      1      False         45            0.275000
# 7                      1      False        131            0.700000
# 8                      1      False        113            0.600000
# 9                      1      False         61            0.300000
# 10                     1      False         50            0.250000
# 11                     1      False         29            0.125000
# 12                     1      False         85            0.450000
# 13                     1      False        120            0.650000
# 14                     1      False         43            0.200000
# 15                     1      False         89            0.375000
# 16                     1      False         46            0.200000
# 17                     1      False         87            0.450000
# 18                     1      False         44            0.250000
# 19                     1      False         23            0.125000
# 20                     1      False        201            0.925000
# 21                     2      False        189            0.800000
# 22                     1      False        110            0.475000
# 23                     1      False         46            0.175000
# 24                     1      False         93            0.475000
# 25                     1      False         26            0.125000
# 26                     1      False        129            0.650000
# 27                     1      False        137            0.750000
# 28                     1      False        161            0.775000
# 29                     1      False         39            0.200000
# ...                  ...        ...        ...                 ...
# 5093                   1      False         82            0.184783
# 5094                   1      False         14            0.032609
# 5095                   1      False         60            0.108696
# 5096                   2      False         34            0.065217
# 5097                   1      False          7            0.010870
# 5098                   1      False         58            0.119565
# 5099                   1      False         86            0.184783
# 5100                   1      False         97            0.184783
# 5101                   1      False         76            0.152174
# 5102                   1      False         40            0.086957
# 5103                   1      False         70            0.152174
# 5104                   1      False        128            0.250000
# 5105                   1      False         74            0.152174
# 5106                   1      False         89            0.163043
# 5107                   1      False         79            0.152174
# 5108                   1      False         74            0.173913
# 5109                   1      False        123            0.250000
# 5110                   1      False         35            0.065217
# 5111                   3      False         91            0.206522
# 5112                   1      False         66            0.141304
# 5113                   1      False         80            0.130435
# 5114                   1      False         63            0.119565
# 5115                   1      False        122            0.195652
# 5116                   1      False         45            0.108696
# 5117                   1      False         24            0.065217
# 5118                   1      False         13            0.032609
# 5119                   3      False        133            0.271739
# 5120                   1      False         27            0.065217
# 5121                   1      False         25            0.065217
# 5122                   1      False         34            0.054348
#
#       percent_len_comment  percent_pos_thread  percent_pos_comment  \
# 0                1.000000            0.014035             0.800000
# 1                0.666667            0.017544             1.000000
# 2                1.000000            0.021053             1.000000
# 3                0.888889            0.028070             1.000000
# 4                1.000000            0.031579             0.500000
# 5                0.757576            0.035088             1.000000
# 6                0.392857            0.038596             0.066667
# 7                1.000000            0.045614             0.200000
# 8                0.857143            0.059649             0.466667
# 9                0.428571            0.066667             0.600000
# 10               0.357143            0.080702             0.866667
# 5113     0.00    0.00      0.500000
# 5114     0.00    0.00      0.500000
# 5115     9.52    4.76      0.586641
# 5116     0.00    0.00      0.465216
# 5117     0.00    0.00      0.439007
# 5118     0.00    0.00      0.439007
# 5119     0.00    0.00      0.398334
# 5120     0.00    0.00      0.552815
# 5121     0.00    0.00      0.439007
# 5122     0.00   16.67      0.439007
#
#                                                 pos_str
# 0     VBZ PRP JJ TO VB NN IN NN TO VB NN TO VB NN RB...
# 1     DT MD VB RB JJ WRB EX VBZ DT NN IN NNS CC PRP ...
# 2     PRP VBP VBG NNP NNP NNP SYM NNP NNP , CC PRP V...
# 3                              RB EX VBZ DT NN IN JJ NN
# 4     NN SYM NNP DT `` NN '' NN VBZ RB VB DT NN JJ W...
# 5     RB JJ WP PRP VBP VBG IN RB , WRB MD PRP RB -LR...
# 6                  PRP RB VBP VBG TO VB RP WRB TO VB DT
# 7     IN PRP VBP DT NN NN TO VB NN , PRP MD RB VB DT...
# 8     PRP VBD VBG PRP MD NN DT NN IN DT NN CC PRP VB...
# 9            RB IN NN NN IN DT NN NN PRP VBZ RB VB DT .
# 10    PRP VBP -LRB- VB -RRB- CC -LRB- JJ NN -RRB- TO...
# 11                               PRP VBP RB VBG DT NN .
# 12    JJS IN DT NN PRP VBP TO VB CC VB NNS IN DT NN ...
# 13    RB RB PRP VBP DT NN TO VB , PRP VBZ PRP IN NN ...
# 14                  PRP RB VBP DT `` NN '' IN NNP NNP .
# 15    PRP VBP TO VB JJ VBG IN DT NN RB IN PRP VBP JJ...
# 16                           PRP MD RB RB JJ TO VB RB .
# 17    PRP VBP DT `` NNP NNP '' NN IN DT JJ JJ NN CC ...
# 18                    VBZ NN VBD DT NN TO VB DT RP RB .
# 19                                  WRB VBP PRP VB DT .
# 20    PRP VBD DT RB JJ NN : IN PRP VBP DT NNP NN CC ...
# 21    NN SYM NNP PRP MD RB VB DT NN -LRB- NN CC NN C...
# 22    NN SYM NN WRB PRP VBD IN JJR NN PRP VBD DT NN ...
# 23                              DT NN NN RB VBZ JJ JJ .
# 24    UH VB DT NN TO VB PRP CC DT NN IN WRB TO VB PR...
# 25                                   VBG DT NNS IN DT .
# 26    LS JJ NN TO VB IN DT NN NN TO VB PRP$ NN NN TO...
# 27    FW FW VBP PRP TO VB NN , FW FW VBP TO VB DT NN...
# 28    NN SYM NN FW VBP RB VB DT NN `` RB JJ WP PRP V...
# 29                          LS MD VB PRP IN FW FW PRP .
# ...                                                 ...
# 5093  VBD TO VB RP NNP NNP TO VB IN PRP MD VB DT JJ ...
# 5094                                     RB PRP$ NN $ :
# 5095        PRP VBP JJ NN NN CC NN NN NN RB DT NN IN NN
# 5096                     PRP MD VB TO VB `` NN NNS , ''
# 5097                                              NNS .
# 5098      PRP VBP RB JJ TO VB JJ RBR NNS , VBP RB PRP .
# 5099  PRP VBP JJ PRP VBP PRP$ JJ NN IN NNS CC WRB PR...
# 5100  CC IN NNS WDT PRP VBP TO VB NN , VBZ RB DT `` ...
# 5101       CC RB DT JJ NN MD VB NNS TO DT JJ JJ NN NN .
# 5102                        PRP VBD DT RB JJ NN IN NN .
# 5103  NN SYM NN PRP VBP RB VB IN VBG DT NN IN NNS VB...
# 5104  EX VBP NNS WDT VBP VBG CC RB CD VBZ TO VB , WP...
# 5105    RB IN PRP , DT JJ NN PRP VBP IN NN VBZ DT NN NN
# 5106  NNP VBZ NNP , NNP , CC NNS IN NNS TO VB TO IN ...
# 5107  PRP RB VBD DT VBN NN -LRB- NN -RRB- WRB PRP VB...
# 5108  PRP VBP RB VB WRB PRP VBD DT NN CC IN PRP VB T...
# 5109  CC PRP VBP PRP RB VBG WRB NNS VBP RB IN JJ . -...
# 5110                            UH , VB VB WP NNS VBP ,
# 5111  PRP MD VB DT NNS IN IN RB DT NN IN DT NN CC DT...
# 5112       PRP VBD RP VBG DT NN NN IN VBN , CC IN DT NN
# 5113           DT VBP DT NN NNS IN VBG IN NNS IN JJ NNS
# 5114               VBG DT NN MD VB JJ IN JJ NNS IN NN .
# 5115  PRP VBZ NN NN NN , JJ NN NNS , NN NN DT NNS -L...
# 5116                PRP VBP WRB DT VBZ VBN PRP MD VB JJ
# 5117                            PRP VBP PRP VB NNS RB .
# 5118                                        NNP NNP . .
# 5119  PRP$ NN VBD TO VB IN DT NN NN , RB DT JJ NN IN...
# 5120                              IN NN , PRP VBP DT NN
# 5121                                 VB PRP IN IN NNS .
# 5122                                   RB IN DT NN NN .
#
# [5123 rows x 111 columns]

# %% [markdown]
# # 2. Train

# %%
from spacy.lang.en import English
eng = spacy.load('en')

parser = English()
lemmatizer = WordNetLemmatizer()

stop_words = list(punctuation) + ["'s","'m","n't","'re","-","'ll",'...'] #+ stopwords.words('english')

# %%
def word_tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        token_str = str(token)
        if token.orth_.isspace():
            continue
        elif str(token) not in stop_words:
            line_tokens.append(lemmatizer.lemmatize(token.lower_))
    return line_tokens

# %%
def pos_tokenize(line):
    line_tokens = []
    tokens = parser(line)
    for token in tokens:
        token_str = str(token)
        if token.orth_.isspace():
            continue
        elif str(token) not in list(punctuation):
            line_tokens.append(str(token))
    return line_tokens

# %%
df_con = source_data[['author_association', 'is_poster', 'quote_len',
       'percent_len_thread', 'percent_len_comment', 'percent_pos_thread',
       'percent_pos_comment', 'is_first_comment', 'is_last_comment',
       'percent_start_time_thread', 'percent_end_time_thread',
       'percent_previous_time_thread', 'percent_next_time_thread',
       'contain_code']]
df_con[(df_con < 0).any(1)]
# Out:
#       author_association  is_poster  quote_len  percent_len_thread  \
# 2528                   1      False         52            0.105263
#
#       percent_len_comment  percent_pos_thread  percent_pos_comment  \
# 2528                  1.0                 1.0                  1.0
#
#       is_first_comment  is_last_comment  percent_start_time_thread  \
# 2528             False             True                        1.0
#
#       percent_end_time_thread  percent_previous_time_thread  \
# 2528                      0.0                      0.000129
#
#       percent_next_time_thread  contain_code
# 2528                 -0.003754         False

# %%
# CAUTIOM
source_data.at[2528, 'percent_next_time_thread'] = 0

# %%
x = source_data[full_feature_name]
y = source_data[label_col]

# %%
source_data
# Out:
#       is_irrelevant                                       Text Content  \
# 0             False  Is it possible to add feature in order to forc...
# 1             False  This can be very useful when there is a lot of...
# 2              True  I'm using VS Code VERSION_NUM  Insider, but I ...
# 3             False      otherwise there is no reason for double click
# 4             False  SCREEN_NAME  The 'preview' function does not k...
# 5             False  Not sure what you are going for here, why woul...
# 6             False      I also am trying to figure out how to do this
# 7             False  because I want the explorer panel to have focu...
# 8             False  I was hoping I could type the name of a file a...
# 9             False  even with KB focus in the explorer window it d...
# 10            False  I want [enter] or [double click] to open the f...
# 11            False                      I'm also having this trouble.
# 12            False  Most of the time I want to drag and drop files...
# 13            False  As soon I select a file to drag, it opens it i...
# 14            False        I really dislike this "feature" of VS Code.
# 15            False  I want to disable automatic previewing of any ...
# 16            False     I would much rather double-click to open only.
# 17            False  I hate the "Preview Tab" feature of the full V...
# 18             True       Has anyone found a way to turn this off yet?
# 19             True                            How do we achieve this?
# 20             True  I found a really klunky workaround - if you ri...
# 21             True  SCREEN_NAME  You can also use the shortcut (Ct...
# 22             True  SCREEN_NAME  when I tried that earlier today i...
# 23            False     This preview feature indeed is super annoying.
# 24            False  Please provide a way to disable it or some gui...
# 25             True                         nthing the calls for this.
# 26            False  i single click to get into the explorer tree t...
# 27            False  i dont want it to do anything, i dont want to ...
# 28            False  SCREEN_NAME  i don't like the comment "Not sur...
# 29            False            i might do it because i missclicked it.
# ...             ...                                                ...
# 5093          False  Decided to check out VS Code to see if it coul...
# 5094           True                                     Just my 2Â¢...
# 5095          False  I use <kbd>Ctrl</kbd> + <kbd>Tab</kbd> quite a...
# 5096          False                 We'd like to keep "preview files,"
# 5097           True                                            Thanks!
# 5098          False  You are always able to memorize few more lines...
# 5099           True  I'm sure you have your own preservative on thi...
# 5100           True  But for issues which you wish to gain traction...
# 5101          False  But possibly the other idea could pave ways to...
# 5102          False           It was a very interesting point of view.
# 5103          False  SCREEN_NAME  I don't think that limiting the n...
# 5104          False  There are somethings that need innovating but ...
# 5105          False  Well for me, every single editor I use for dev...
# 5106          False  Code has Sublime, Atom, and non-editors like b...
# 5107          False  I recently used a tabbed editor (Koding.io) wh...
# 5108          False  I don't remember how I opened a file or whethe...
# 5109          False  and I find it really disconcerting when files ...
# 5110          False                Please, please do what browsers do,
# 5111          False  we will shrink the tabs so that only the name ...
# 5112          False  I tried out using the file history as suggeste...
# 5113          False  these are the default shortcuts for navigating...
# 5114           True  Double-clicking a tab may be useful for other ...
# 5115          False  it has max tab width, left/right scroll button...
# 5116          False      I hope when this is built it will be optional
# 5117          False                           I hope we get tabs soon!
# 5118           True                                      Great News ..
# 5119           True  Our intent was to focus on the interaction flo...
# 5120          False                        for example, I love the way
# 5121          False                          Keep it along with tabs ?
# 5122          False                     then thatâs all Iâd need/want.
#
#       author_association  is_poster  quote_len  percent_len_thread  \
# 0                      0       True        152            0.750000
# 1                      0       True         95            0.500000
# 2                      2      False        153            0.650000
# 3                      1       True         45            0.200000
# 4                      2      False        190            0.825000
# 5                      2      False        127            0.625000
# 6                      1      False         45            0.275000
# 7                      1      False        131            0.700000
# 8                      1      False        113            0.600000
# 9                      1      False         61            0.300000
# 10                     1      False         50            0.250000
# 11                     1      False         29            0.125000
# 12                     1      False         85            0.450000
# 13                     1      False        120            0.650000
# 14                     1      False         43            0.200000
# 15                     1      False         89            0.375000
# 16                     1      False         46            0.200000
# 17                     1      False         87            0.450000
# 18                     1      False         44            0.250000
# 19                     1      False         23            0.125000
# 20                     1      False        201            0.925000
# 21                     2      False        189            0.800000
# 22                     1      False        110            0.475000
# 23                     1      False         46            0.175000
# 24                     1      False         93            0.475000
# 25                     1      False         26            0.125000
# 26                     1      False        129            0.650000
# 27                     1      False        137            0.750000
# 28                     1      False        161            0.775000
# 29                     1      False         39            0.200000
# ...                  ...        ...        ...                 ...
# 5093                   1      False         82            0.184783
# 5094                   1      False         14            0.032609
# 5095                   1      False         60            0.108696
# 5096                   2      False         34            0.065217
# 5097                   1      False          7            0.010870
# 5098                   1      False         58            0.119565
# 5099                   1      False         86            0.184783
# 5100                   1      False         97            0.184783
# 5101                   1      False         76            0.152174
# 5102                   1      False         40            0.086957
# 5103                   1      False         70            0.152174
# 5104                   1      False        128            0.250000
# 5105                   1      False         74            0.152174
# 5106                   1      False         89            0.163043
# 5107                   1      False         79            0.152174
# 5108                   1      False         74            0.173913
# 5109                   1      False        123            0.250000
# 5110                   1      False         35            0.065217
# 5111                   3      False         91            0.206522
# 5112                   1      False         66            0.141304
# 5113                   1      False         80            0.130435
# 5114                   1      False         63            0.119565
# 5115                   1      False        122            0.195652
# 5116                   1      False         45            0.108696
# 5117                   1      False         24            0.065217
# 5118                   1      False         13            0.032609
# 5119                   3      False        133            0.271739
# 5120                   1      False         27            0.065217
# 5121                   1      False         25            0.065217
# 5122                   1      False         34            0.054348
#
#       percent_len_comment  percent_pos_thread  percent_pos_comment  \
# 0                1.000000            0.014035             0.800000
# 1                0.666667            0.017544             1.000000
# 2                1.000000            0.021053             1.000000
# 3                0.888889            0.028070             1.000000
# 4                1.000000            0.031579             0.500000
# 5                0.757576            0.035088             1.000000
# 6                0.392857            0.038596             0.066667
# 7                1.000000            0.045614             0.200000
# 8                0.857143            0.059649             0.466667
# 9                0.428571            0.066667             0.600000
# 10               0.357143            0.080702             0.866667
# 11               0.192308            0.091228             0.333333
# 12               0.692308            0.094737             0.666667
# 13               1.000000            0.098246             1.000000
# 14               0.533333            0.105263             0.400000
# 15               1.000000            0.108772             0.600000
# 16               0.533333            0.112281             0.800000
# 17               1.000000            0.119298             0.500000
# 18               0.555556            0.122807             1.000000
# 19               0.333333            0.115789             1.000000
# 20               1.000000            0.126316             1.000000
# 21               1.000000            0.129825             1.000000
# 22               1.000000            0.133333             1.000000
# 23               0.368421            0.136842             0.500000
# 24               1.000000            0.140351             1.000000
# 25               0.161290            0.143860             0.090909
# 26               0.838710            0.147368             0.181818
# 27               0.967742            0.150877             0.272727
# 28               1.000000            0.157895             0.454545
# 29               0.258065            0.161404             0.545455
# ...                   ...                 ...                  ...
# 5093             0.435897            0.572637             0.166667
# 5094             0.073171            0.593035             1.000000
# 5     RB JJ WP PRP VBP VBG IN RB , WRB MD PRP RB -LR...
# 6                  PRP RB VBP VBG TO VB RP WRB TO VB DT
# 7     IN PRP VBP DT NN NN TO VB NN , PRP MD RB VB DT...
# 8     PRP VBD VBG PRP MD NN DT NN IN DT NN CC PRP VB...
# 9            RB IN NN NN IN DT NN NN PRP VBZ RB VB DT .
# 10    PRP VBP -LRB- VB -RRB- CC -LRB- JJ NN -RRB- TO...
# 11                               PRP VBP RB VBG DT NN .
# 12    JJS IN DT NN PRP VBP TO VB CC VB NNS IN DT NN ...
# 13    RB RB PRP VBP DT NN TO VB , PRP VBZ PRP IN NN ...
# 14                  PRP RB VBP DT `` NN '' IN NNP NNP .
# 15    PRP VBP TO VB JJ VBG IN DT NN RB IN PRP VBP JJ...
# 16                           PRP MD RB RB JJ TO VB RB .
# 17    PRP VBP DT `` NNP NNP '' NN IN DT JJ JJ NN CC ...
# 18                    VBZ NN VBD DT NN TO VB DT RP RB .
# 19                                  WRB VBP PRP VB DT .
# 20    PRP VBD DT RB JJ NN : IN PRP VBP DT NNP NN CC ...
# 21    NN SYM NNP PRP MD RB VB DT NN -LRB- NN CC NN C...
# 22    NN SYM NN WRB PRP VBD IN JJR NN PRP VBD DT NN ...
# 23                              DT NN NN RB VBZ JJ JJ .
# 24    UH VB DT NN TO VB PRP CC DT NN IN WRB TO VB PR...
# 25                                   VBG DT NNS IN DT .
# 26    LS JJ NN TO VB IN DT NN NN TO VB PRP$ NN NN TO...
# 27    FW FW VBP PRP TO VB NN , FW FW VBP TO VB DT NN...
# 28    NN SYM NN FW VBP RB VB DT NN `` RB JJ WP PRP V...
# 29                          LS MD VB PRP IN FW FW PRP .
# ...                                                 ...
# 5093  VBD TO VB RP NNP NNP TO VB IN PRP MD VB DT JJ ...
# 5094                                     RB PRP$ NN $ :
# 5095        PRP VBP JJ NN NN CC NN NN NN RB DT NN IN NN
# 5096                     PRP MD VB TO VB `` NN NNS , ''
# 5097                                              NNS .
# 5098      PRP VBP RB JJ TO VB JJ RBR NNS , VBP RB PRP .
# 5099  PRP VBP JJ PRP VBP PRP$ JJ NN IN NNS CC WRB PR...
# 5100  CC IN NNS WDT PRP VBP TO VB NN , VBZ RB DT `` ...
# 5101       CC RB DT JJ NN MD VB NNS TO DT JJ JJ NN NN .
# 5102                        PRP VBD DT RB JJ NN IN NN .
# 5103  NN SYM NN PRP VBP RB VB IN VBG DT NN IN NNS VB...
# 5104  EX VBP NNS WDT VBP VBG CC RB CD VBZ TO VB , WP...
# 5105    RB IN PRP , DT JJ NN PRP VBP IN NN VBZ DT NN NN
# 5106  NNP VBZ NNP , NNP , CC NNS IN NNS TO VB TO IN ...
# 5107  PRP RB VBD DT VBN NN -LRB- NN -RRB- WRB PRP VB...
# 5108  PRP VBP RB VB WRB PRP VBD DT NN CC IN PRP VB T...
# 5109  CC PRP VBP PRP RB VBG WRB NNS VBP RB IN JJ . -...
# 5110                            UH , VB VB WP NNS VBP ,
# 5111  PRP MD VB DT NNS IN IN RB DT NN IN DT NN CC DT...
# 5112       PRP VBD RP VBG DT NN NN IN VBN , CC IN DT NN
# 5113           DT VBP DT NN NNS IN VBG IN NNS IN JJ NNS
# 5114               VBG DT NN MD VB JJ IN JJ NNS IN NN .
# 5115  PRP VBZ NN NN NN , JJ NN NNS , NN NN DT NNS -L...
# 5116                PRP VBP WRB DT VBZ VBN PRP MD VB JJ
# 5117                            PRP VBP PRP VB NNS RB .
# 5118                                        NNP NNP . .
# 5119  PRP$ NN VBD TO VB IN DT NN NN , RB DT JJ NN IN...
# 5120                              IN NN , PRP VBP DT NN
# 5121                                 VB PRP IN IN NNS .
# 5122                                   RB IN DT NN NN .
#
# [5123 rows x 111 columns]

# %%
# followed the tutorial at: https://zablo.net/blog/post/pandas-dataframe-in-scikit-learn-feature-union/index.html
class PandasFeatureUnion(FeatureUnion):
    def fit_transform(self, X, y=None, **fit_params):
        self._validate_transformers()
        result = Parallel(n_jobs=self.n_jobs)(
            delayed(_fit_transform_one)(
                transformer=trans,
                X=X,
                y=y,
                weight=weight,
                **fit_params)
            for name, trans, weight in self._iter())
        if not result:
            return np.zeros((X.shape[0], 0))
        Xs, transformers = zip(*result)
        self._update_transformer_list(transformers)
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

    def merge_dataframes_by_column(self, Xs):
        return pd.concat(Xs, axis="columns", copy=False)

    def transform(self, X):
        Xs = Parallel(n_jobs=self.n_jobs)(
            delayed(_transform_one)(
                transformer=trans,
                X=X,
                y=None,
                weight=weight)
            for name, trans, weight in self._iter())
        if not Xs:
            return np.zeros((X.shape[0], 0))
        if any(sparse.issparse(f) for f in Xs):
            Xs = sparse.hstack(Xs).tocsr()
        else:
            Xs = self.merge_dataframes_by_column(Xs)
        return Xs

# %%
def BuildPipeline(use_tfidf, use_conversational, use_liwc, use_politeness, use_pos_tfidf, classifier, num_select_k):
    feature_flag_str = classifier
    ready_feature_name = []
    if num_select_k != -1:
        feature_flag_str = feature_flag_str + '_k' + str(num_select_k)
    if use_conversational:
        feature_flag_str = feature_flag_str + '_conver'
        ready_feature_name += conver_feature_name
    if use_liwc:
        feature_flag_str = feature_flag_str + '_liwc'
        ready_feature_name += liwc_feature_name
    if use_politeness:
        feature_flag_str = feature_flag_str + '_polite'
        ready_feature_name += politeness_feature_name

    ready_feature = FilterDFTool.GetDataColByNames(ready_feature_name)
    
    tfidf_features = Pipeline([
        ('extract_field', FunctionTransformer(lambda x: x['Text Content'], validate=False)),
        ('vect', DenseTfidfVectorizer(tokenizer=word_tokenize, analyzer='word'))
    ])

    pos_tfidf_features = Pipeline([
        ('extract_field', FunctionTransformer(lambda x: x['pos_str'], validate=False)),
        ('vect', DenseTfidfVectorizer(tokenizer=pos_tokenize, analyzer='word'))
    ])

    if use_tfidf and use_pos_tfidf:
        feature_flag_str = feature_flag_str + '_tfidf'
        feature_flag_str = feature_flag_str + '_postfidf'
        feature_union = PandasFeatureUnion([
            ('ready_feature', ready_feature),
            ('tfidf_feature', tfidf_features),
            ('pos_tfidf_feature', pos_tfidf_features)
        ])
        param_grid = {
            'feature__pos_tfidf_feature__vect__ngram_range': ((1,1),(1,2)),
            'feature__tfidf_feature__vect__ngram_range': ((1,1),(1,2)),
        }
    elif use_tfidf:
        feature_flag_str = feature_flag_str + '_tfidf'
        feature_union = PandasFeatureUnion([
            ('ready_feature', ready_feature),
            ('tfidf_feature', tfidf_features)
        ])
        param_grid = {
            'feature__tfidf_feature__vect__ngram_range': ((1,1),(1,2)),
        }

    elif use_pos_tfidf:
        feature_flag_str = feature_flag_str + '_postfidf'
        feature_union = PandasFeatureUnion([
            ('ready_feature', ready_feature),
            ('pos_tfidf_feature', pos_tfidf_features)
        ])
        param_grid = {
            'feature__pos_tfidf_feature__vect__ngram_range': ((1,1),(1,2)),
        }
    else:
        feature_union = PandasFeatureUnion([
            ('ready_feature', ready_feature)
        ])
        param_grid = {}

    if classifier == 'svm':
        if num_select_k != -1:
            pipeline = Imb_Pipeline([
                ('feature', feature_union),
                ('select_k', SelectKBest(chi2, k=num_select_k)),
                ('clf', LinearSVC(class_weight='balanced'))
            ])
        else:
            pipeline = Imb_Pipeline([
                ('feature', feature_union),
                ('clf', LinearSVC(class_weight='balanced'))
            ])
        param_grid['clf__C'] = (0.01, 0.1, 1, 10)
        
    else: # complement NB
        if num_select_k != -1:
            pipeline = Imb_Pipeline([
                ('feature', feature_union),
                ('select_k', SelectKBest(chi2, k=num_select_k)),
                ('clf', ComplementNB())
            ])
        else:
            pipeline = Imb_Pipeline([
                ('feature', feature_union),
                ('clf', ComplementNB())
            ])
        param_grid['clf__alpha'] = (0.01, 0.1, 1, 10)
        
    return pipeline, param_grid, feature_flag_str

# %%
### Define and create the scoring functions

def score_func(y_true, y_pred, score_index, i):
    return(precision_recall_fscore_support(y_true,y_pred)[score_index][i])

def avg_score(y_true, y_pred, score_index):
    return precision_recall_fscore_support(y_true,y_pred,average='weighted')[score_index]

def sum_support(y_true, y_pred):
    return len(y_true)

### Create partials for each of the metrics returned
score_funcs = {v: partial(score_func, score_index=k) for k, v in {0:'precision',1:'recall',2:'fscore',3:'support'}.items()}
prec_score = partial(score_func, score_index=0)
update_wrapper(prec_score,score_func)
rec_score = partial(score_func, score_index=1)
update_wrapper(rec_score,score_func)
f_score = partial(score_func, score_index=2)
update_wrapper(f_score,score_func)
support_score = partial(score_func, score_index=3)
update_wrapper(support_score,score_func)

### Create a callable scoring function for each of the metrics for each classification label
scorer = {}
for label_id in range(0,2):
    scorer['label'+str(label_id)+'_precision'] = make_scorer(prec_score, i=label_id)
    scorer['label'+str(label_id)+'_recall'] = make_scorer(rec_score, i=label_id)
    scorer['label'+str(label_id)+'_fscore'] = make_scorer(f_score, i=label_id)
    scorer['label'+str(label_id)+'_support'] = make_scorer(support_score, i=label_id)

### Create a callable scoring function for avg/total of the metrics across classification labels
scorer['avg_precision'] = make_scorer(avg_score,score_index=0)
scorer['avg_recall'] = make_scorer(avg_score,score_index=1)
scorer['avg_fscore'] = make_scorer(avg_score,score_index=2)
scorer['total_support'] = make_scorer(sum_support)

# %%
# To be used within GridSearch
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# To be used in outer CV
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %%
labels = ['argumentative', 'non-argumentative']

# %%
for experiment in experiment_setups:
    use_tfidf = experiment[0]
    use_conver = experiment[1]
    use_liwc = experiment[2]
    use_polite = experiment[3]
    use_pos_tfidf = experiment[4]
    classifier = experiment[5]
    num_select_k = experiment[6]
    svm_pipeline, param_grid, feature_flag_str = BuildPipeline(use_tfidf, use_conver, use_liwc, use_polite, use_pos_tfidf, classifier, num_select_k)
    
    # write to grid_search file
    f= open("results_argumentative/5Fold_grid_search_" + feature_flag_str + ".txt","w+")

    f.write("Performing grid search...\n")
    f.write("pipeline:" + ' '.join([name for name, _ in svm_pipeline.steps]) + "\n")
    f.write("parameters:")
    f.write(str(param_grid) + '\n')
    t0 = time.time()

    clf = GridSearchCV(svm_pipeline, param_grid, cv=inner_cv, scoring='f1_weighted')
    clf_results = cross_validate(clf, X=x, y=y, cv=outer_cv, scoring=scorer, return_train_score=True)

    f.write("done in %0.3fs\n" % (time.time() - t0))

    f.close() 
    
    train_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])
    test_report = pd.DataFrame(columns=['Precision', 'Recall', 'F1-score', 'Support'])

    result_dict = {}

    writer = pd.ExcelWriter('results_argumentative/5Fold_result_'+ feature_flag_str +'.xlsx')

    datalength = 0

    for i in range(0,5):
        for label_id in range(0,2):
            train_report.loc[labels[label_id], :] = [clf_results['train_label'+str(label_id)+'_precision'][i],clf_results['train_label'+str(label_id)+'_recall'][i],clf_results['train_label'+str(label_id)+'_fscore'][i],clf_results['train_label'+str(label_id)+'_support'][i]]
            test_report.loc[labels[label_id], :] = [clf_results['test_label'+str(label_id)+'_precision'][i],clf_results['test_label'+str(label_id)+'_recall'][i],clf_results['test_label'+str(label_id)+'_fscore'][i],clf_results['test_label'+str(label_id)+'_support'][i]]

        train_report.loc['Avg/Total', :] = [clf_results['train_avg_precision'][i],clf_results['train_avg_recall'][i],clf_results['train_avg_fscore'][i],clf_results['train_total_support'][i]]
        test_report.loc['Avg/Total', :] = [clf_results['test_avg_precision'][i],clf_results['test_avg_recall'][i],clf_results['test_avg_fscore'][i],clf_results['test_total_support'][i]]

        fold_index = pd.DataFrame(data=[{'Fold':'Fold '+str(i)}])
        fold_index.to_excel(writer,'result',startrow=datalength, index=False)
        datalength+=(len(fold_index)+2)
        train_report.to_excel(writer,'result',startrow=datalength)
        datalength+=(len(train_report)+2)
        test_report.to_excel(writer,'result',startrow=datalength)
        datalength+=(len(test_report)+2)

        result_dict['result_train_'+str(i)] = train_report
        result_dict['result_test_'+str(i)] = test_report

        train_report = train_report.astype(float).round(2)
        test_report = test_report.astype(float).round(2)

        print("\n------------------------- FOLD "+str(i)+": -------------------------")
        print("\nTraining Results:")
        print(train_report)
        print("\nTest Results:")
        print(test_report)

    writer.save()
# Out:
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         1.00    0.99      0.99   2427.0
# irrelevant       0.99    1.00      0.99   1671.0
# Avg/Total        0.99    0.99      0.99   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.80    0.83      0.82    607.0
# irrelevant       0.74    0.70      0.72    418.0
# Avg/Total        0.78    0.78      0.78   1025.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         1.00    0.99      1.00   2427.0
# irrelevant       0.99    1.00      0.99   1671.0
# Avg/Total        0.99    0.99      0.99   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.80    0.85      0.83    607.0
# irrelevant       0.76    0.69      0.73    418.0
# Avg/Total        0.79    0.79      0.79   1025.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         1.00     1.0       1.0   2427.0
# irrelevant       0.99     1.0       1.0   1671.0
# Avg/Total        1.00     1.0       1.0   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.79    0.86      0.82    607.0
# irrelevant       0.77    0.67      0.71    418.0
# Avg/Total        0.78    0.78      0.78   1025.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.93    0.94      0.94   2427.0
# irrelevant       0.92    0.90      0.91   1671.0
# Avg/Total        0.93    0.93      0.93   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.79    0.87      0.82    607.0
# irrelevant       0.77    0.66      0.71    418.0
# Avg/Total        0.78    0.78      0.78   1025.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.93    0.95      0.94   2428.0
# irrelevant       0.93    0.89      0.91   1672.0
# Avg/Total        0.93    0.93      0.93   4100.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.80    0.86      0.83    606.0
# irrelevant       0.77    0.69      0.73    417.0
# Avg/Total        0.79    0.79      0.79   1023.0
#
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.77    0.77      0.77   2427.0
# irrelevant       0.67    0.67      0.67   1671.0
# Avg/Total        0.73    0.73      0.73   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.70      0.70    607.0
# irrelevant       0.57    0.58      0.57    418.0
# Avg/Total        0.65    0.65      0.65   1025.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.72    0.78      0.75   2427.0
# irrelevant       0.64    0.57      0.60   1671.0
# Avg/Total        0.69    0.69      0.69   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.69    0.73      0.71    607.0
# irrelevant       0.57    0.52      0.55    418.0
# Avg/Total        0.64    0.65      0.64   1025.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.77    0.77      0.77   2427.0
# irrelevant       0.67    0.67      0.67   1671.0
# Avg/Total        0.73    0.73      0.73   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.73    0.71      0.72    607.0
# irrelevant       0.60    0.62      0.61    418.0
# Avg/Total        0.68    0.68      0.68   1025.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.78    0.78      0.78   2427.0
# irrelevant       0.68    0.69      0.68   1671.0
# Avg/Total        0.74    0.74      0.74   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.70    0.71      0.70    607.0
# irrelevant       0.57    0.56      0.56    418.0
# Avg/Total        0.65    0.65      0.65   1025.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.72    0.77      0.75   2428.0
# irrelevant       0.63    0.56      0.60   1672.0
# Avg/Total        0.68    0.69      0.68   4100.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.73      0.72    606.0
# irrelevant       0.59    0.56      0.57    417.0
# Avg/Total        0.66    0.66      0.66   1023.0
#
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.79    0.82      0.81   2427.0
# irrelevant       0.73    0.69      0.71   1671.0
# Avg/Total        0.77    0.77      0.77   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.77    0.82      0.79    607.0
# irrelevant       0.71    0.65      0.68    418.0
# Avg/Total        0.75    0.75      0.75   1025.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.82    0.71      0.76   2427.0
# irrelevant       0.65    0.78      0.71   1671.0
# Avg/Total        0.75    0.74      0.74   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.81    0.69      0.74    607.0
# irrelevant       0.63    0.76      0.69    418.0
# Avg/Total        0.73    0.72      0.72   1025.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.75    0.86      0.80   2427.0
# irrelevant       0.74    0.58      0.65   1671.0
# Avg/Total        0.74    0.74      0.74   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.75    0.87      0.80    607.0
# irrelevant       0.75    0.57      0.65    418.0
# Avg/Total        0.75    0.75      0.74   1025.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.78    0.79      0.78   2427.0
# irrelevant       0.69    0.67      0.68   1671.0
# Avg/Total        0.74    0.74      0.74   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.76    0.79      0.78    607.0
# irrelevant       0.68    0.63      0.66    418.0
# Avg/Total        0.73    0.73      0.73   1025.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.85    0.60      0.71   2428.0
# irrelevant       0.60    0.85      0.70   1672.0
# Avg/Total        0.75    0.70      0.70   4100.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.85    0.61      0.71    606.0
# irrelevant       0.60    0.84      0.70    417.0
# Avg/Total        0.75    0.70      0.70   1023.0
#
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.79    0.84      0.81   2427.0
# irrelevant       0.75    0.67      0.71   1671.0
# Avg/Total        0.77    0.77      0.77   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.77    0.83      0.80    607.0
# irrelevant       0.72    0.65      0.68    418.0
# Avg/Total        0.75    0.75      0.75   1025.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.76    0.90      0.82   2427.0
# irrelevant       0.79    0.58      0.67   1671.0
# Avg/Total        0.77    0.77      0.76   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.73    0.88      0.80    607.0
# irrelevant       0.75    0.54      0.63    418.0
# Avg/Total        0.74    0.74      0.73   1025.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.77    0.84      0.81   2427.0
# irrelevant       0.74    0.64      0.69   1671.0
# Avg/Total        0.76    0.76      0.76   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.76    0.85      0.80    607.0
# irrelevant       0.74    0.61      0.67    418.0
# Avg/Total        0.75    0.75      0.75   1025.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.79    0.78      0.78   2427.0
# irrelevant       0.69    0.70      0.69   1671.0
# Avg/Total        0.75    0.75      0.75   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.78    0.77      0.77    607.0
# irrelevant       0.67    0.68      0.67    418.0
# Avg/Total        0.73    0.73      0.73   1025.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.86    0.64      0.73   2428.0
# irrelevant       0.62    0.84      0.71   1672.0
# Avg/Total        0.76    0.72      0.72   4100.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.84    0.62      0.71    606.0
# irrelevant       0.60    0.83      0.69    417.0
# Avg/Total        0.74    0.70      0.70   1023.0
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.99    0.99      0.99   2427.0
# irrelevant       0.99    0.98      0.98   1671.0
# Avg/Total        0.99    0.99      0.99   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.79    0.87      0.83    607.0
# irrelevant       0.78    0.67      0.72    418.0
# Avg/Total        0.79    0.79      0.78   1025.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.99    0.99      0.99   2427.0
# irrelevant       0.99    0.98      0.98   1671.0
# Avg/Total        0.99    0.99      0.99   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.78    0.84      0.81    607.0
# irrelevant       0.74    0.65      0.69    418.0
# Avg/Total        0.76    0.76      0.76   1025.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.99    0.99      0.99   2427.0
# irrelevant       0.98    0.98      0.98   1671.0
# Avg/Total        0.99    0.99      0.99   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.79    0.85      0.82    607.0
# irrelevant       0.75    0.67      0.71    418.0
# Avg/Total        0.77    0.78      0.77   1025.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.99    0.99      0.99   2427.0
# irrelevant       0.98    0.98      0.98   1671.0
# Avg/Total        0.99    0.99      0.99   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.78    0.86      0.82    607.0
# irrelevant       0.76    0.65      0.70    418.0
# Avg/Total        0.77    0.77      0.77   1025.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.99    0.99      0.99   2428.0
# irrelevant       0.99    0.98      0.98   1672.0
# Avg/Total        0.99    0.99      0.99   4100.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.79    0.85      0.82    606.0
# irrelevant       0.75    0.67      0.71    417.0
# Avg/Total        0.77    0.78      0.77   1023.0
#
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.73    0.81      0.77   2427.0
# irrelevant       0.67    0.56      0.61   1671.0
# Avg/Total        0.70    0.71      0.70   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.67    0.77      0.72    607.0
# irrelevant       0.58    0.46      0.51    418.0
# Avg/Total        0.64    0.64      0.64   1025.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.75    0.81      0.78   2427.0
# irrelevant       0.69    0.61      0.65   1671.0
# Avg/Total        0.72    0.73      0.72   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.69    0.75      0.72    607.0
# irrelevant       0.58    0.51      0.54    418.0
# Avg/Total        0.64    0.65      0.65   1025.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.73    0.83      0.78   2427.0
# irrelevant       0.69    0.55      0.61   1671.0
# Avg/Total        0.71    0.71      0.71   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.80      0.75    607.0
# irrelevant       0.64    0.52      0.57    418.0
# Avg/Total        0.68    0.68      0.68   1025.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.73    0.82      0.77   2427.0
# irrelevant       0.68    0.56      0.62   1671.0
# Avg/Total        0.71    0.71      0.71   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.68    0.79      0.73    607.0
# irrelevant       0.60    0.46      0.53    418.0
# Avg/Total        0.65    0.66      0.65   1025.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.75    0.80      0.77   2428.0
# irrelevant       0.68    0.61      0.64   1672.0
# Avg/Total        0.72    0.72      0.72   4100.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.69    0.73      0.71    606.0
# irrelevant       0.57    0.52      0.54    417.0
# Avg/Total        0.64    0.64      0.64   1023.0
#
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.70    0.79      0.74   2427.0
# irrelevant       0.63    0.52      0.57   1671.0
# Avg/Total        0.67    0.68      0.67   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.80      0.75    607.0
# irrelevant       0.64    0.52      0.58    418.0
# Avg/Total        0.68    0.68      0.68   1025.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.80      0.75   2427.0
# irrelevant       0.64    0.52      0.57   1671.0
# Avg/Total        0.68    0.68      0.68   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.69    0.80      0.74    607.0
# irrelevant       0.62    0.49      0.55    418.0
# Avg/Total        0.66    0.67      0.66   1025.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.78      0.74   2427.0
# irrelevant       0.63    0.53      0.57   1671.0
# Avg/Total        0.67    0.68      0.67   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.70    0.77      0.74    607.0
# irrelevant       0.61    0.53      0.57    418.0
# Avg/Total        0.67    0.67      0.67   1025.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.80      0.75   2427.0
# irrelevant       0.64    0.53      0.58   1671.0
# Avg/Total        0.68    0.69      0.68   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.68    0.77      0.72    607.0
# irrelevant       0.59    0.49      0.53    418.0
# Avg/Total        0.65    0.65      0.65   1025.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.79      0.74   2428.0
# irrelevant       0.63    0.53      0.57   1672.0
# Avg/Total        0.67    0.68      0.67   4100.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.70    0.78      0.74    606.0
# irrelevant       0.62    0.52      0.57    417.0
# Avg/Total        0.67    0.68      0.67   1023.0
#
# ------------------------- FOLD 0: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.79      0.75   2427.0
# irrelevant       0.63    0.52      0.57   1671.0
# Avg/Total        0.67    0.68      0.67   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.80      0.75    607.0
# irrelevant       0.64    0.53      0.58    418.0
# Avg/Total        0.68    0.69      0.68   1025.0
#
# ------------------------- FOLD 1: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.80      0.75   2427.0
# irrelevant       0.64    0.53      0.58   1671.0
# Avg/Total        0.68    0.69      0.68   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.69    0.80      0.74    607.0
# irrelevant       0.62    0.49      0.55    418.0
# Avg/Total        0.67    0.67      0.66   1025.0
#
# ------------------------- FOLD 2: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.79      0.75   2427.0
# irrelevant       0.63    0.53      0.58   1671.0
# Avg/Total        0.68    0.68      0.68   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.78      0.74    607.0
# irrelevant       0.62    0.53      0.57    418.0
# Avg/Total        0.67    0.68      0.67   1025.0
#
# ------------------------- FOLD 3: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.80      0.75   2427.0
# irrelevant       0.65    0.54      0.59   1671.0
# Avg/Total        0.69    0.69      0.69   4098.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.69    0.77      0.73    607.0
# irrelevant       0.59    0.49      0.54    418.0
# Avg/Total        0.65    0.66      0.65   1025.0
#
# ------------------------- FOLD 4: -------------------------
#
# Training Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.79      0.75   2428.0
# irrelevant       0.63    0.53      0.58   1672.0
# Avg/Total        0.68    0.68      0.68   4100.0
#
# Test Results:
#             Precision  Recall  F1-score  Support
# relevant         0.71    0.79      0.75    606.0
# irrelevant       0.63    0.53      0.58    417.0
# Avg/Total        0.68    0.68      0.68   1023.0
